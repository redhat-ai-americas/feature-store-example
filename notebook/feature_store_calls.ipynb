# %%
# !pip install feast[postgres]==0.59.0 grpcio

# %%
from feast import FeatureStore

fs_insurance = FeatureStore(fs_yaml_file='/opt/app-root/src/feast-config/insurance_demo')

# %%
fs_insurance.list_feature_views()
